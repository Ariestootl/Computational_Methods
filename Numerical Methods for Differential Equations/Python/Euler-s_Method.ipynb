# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Solve the following initial value problem using Forward Euler Scheme and Backward Euler Scheme
#
# $$
# \frac{dy}{dt} - y = t, \quad t \in [0,5]
# $$
#
# The initial condition is:$\quad y(0) = 0$
#
# The True Solution is:
# $$
# y(t) = (-t-1) + e^t
# $$

# %%
##Define the following functions

def f(t, y):
    return y + t

def forward_euler(y0, h, N, t, f):
    y = np.zeros(N)
    y[0] = y0
    for i in range(0, N-1):
        y[i+1] = y[i] + h*f(t[i], y[i])
    return y

def backward_euler(y0, h, N, t, f):
    '''
    Backward Euler Scheme via Fixed Point Iteration Method
    '''
    y = np.zeros(N)
    y[0] = y0
    for i in range(0, N-1):
        y[i+1] = (y[i] + h*t[i+1]) / (1 - h);
    return y

# %%
a=0; b=5; N=100; t = np.linspace(a,b,N); 
ftrue = lambda t: (-t-1)+ np.exp(t); ###True Solution
h = (t[1]-t[0]) ;  y0 = 0;

y1 = forward_euler(y0, h, N, t, f);
y2 = backward_euler(y0, h, N, t, f);


plt.figure(figsize=(10, 6))
plt.plot(t, ftrue(t), linestyle="-", linewidth=2.0, label="True solution")
plt.plot(t, y1, linestyle="-", linewidth=2.0, color="#770000", label="Forward Euler")
plt.plot(t, y2, linestyle="-", linewidth=2.0, color="#005500", label="Backward Euler")
plt.legend(loc="upper left", fontsize=16)
plt.xlabel("t", fontsize=16)
plt.ylabel("y", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid(True)
plt.show()

# %%
# Call the Euler method
t1, y1 = forward_euler(y0, h, N, t, f)

# Plot the result
plt.plot(t1, y1, 'r', label='Forward Euler')
plt.plot(t, ftrue(t), 'b--', label='True Solution')
plt.xlabel('Time')
plt.ylabel('y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 5
#       2 t1, y1 = forward_euler(y0, h, N, t, f)
#       4 # Plot the result
# ----> 5 plt.plot(t1, y1, 'r', label='Forward Euler')
#       6 plt.plot(t, ftrue(t), 'b--', label='True Solution')
#       7 plt.xlabel('Time')
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#    3832         scaley=scaley,
#    3833         **({"data": data} if data is not None else {}),
#    3834         **kwargs,
#    3835     )
#
# ...

# %%
y1.shape
# Out:
# (101,)
